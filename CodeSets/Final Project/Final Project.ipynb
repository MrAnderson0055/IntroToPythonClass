# %%
## New notebook for project

# %%
greeting = "  Hello, little people of Earth!      "
length= len (greeting) # used to get the length of the string
div_by_5=(length%5) # this is used to show if its divisible by 5
greetings=greeting.strip() #used to strip the spaces and clean it up
new_phrase={}
new_phrase=greetings[:5] #used to capture the first 5 characters

new_phrase2=new_phrase + "o"*59 #after some thought, I couldn't figure this out and reattempt




print (new_phrase2)
# Out:
# Helloooooooooooooooooooooooooooooooooooooooooooooooooooooooooooo

# %%
# Problem 2
# I thought a class might be needed but further reading showed it might make it more complicated
number=int(input('Please enter a number for a surprise'))
print (number)
def wow_kazow(number):
    new_number=len(number)
    if new_number % 5 == 0 and number % 7 == 0:
        print ("wow_kazow") 
    elif number % 5 ==0: #to chack if div by 5 
        print ("wow")        
    elif number % 7 == 0: # to check if div by 7
        print ("kazow")

    else:
        return number # in case neither div by 5 or 7 

def main():
    for i in range (41,90):
        print (wow_kazow(i))
# Out:
# Please enter a number for a surprise 10
# 10

# %%
class 


class
