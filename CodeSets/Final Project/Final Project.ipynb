# %%
greetings = "Hello, little people of Earth!"
length=len(greetings) #making it read the characters in the string
is_div_by5= (length%5==0) #to divide each character in the string
print (is_div_by5) # to print the string being divisible by 5 true or false
# Out:
# True
