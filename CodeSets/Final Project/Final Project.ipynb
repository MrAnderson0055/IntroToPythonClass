# %%
# Got ahead of myself and took out the spaces... adding them back in 
greeting = "Hello, little people of Earth!         "

length=len(greeting) #making it read the characters in the string 

is_div_by5= (length%5==0) #to divide each character in the string
greetings=greeting.strip() # this is to remove any spaces, as I left strip blank.
new_phrase=
print (greetings) # Now to print the message and see if strip worked
# Out:
# Hello, little people of Earth!
